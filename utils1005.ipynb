# %% [markdown]
# <a href="https://colab.research.google.com/github/szokrondorka/bioinf21/blob/main/utils1005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
data_path = 'drive/My Drive/Case_Study2/PFXXXXXX'
file_name_list = os.listdir(data_path)

# %%
file_name_list[0]
# Out:
# 'PF00207_full_length_sequences.fasta'

# %%
open('drive/My Drive/Case_Study2/PFXXXXXX/PF00207_full_length_sequences.fasta', 'r')
# Out:
# <_io.TextIOWrapper name='drive/My Drive/Case_Study2/PFXXXXXX/PF00207_full_length_sequences.fasta' mode='r' encoding='UTF-8'>
